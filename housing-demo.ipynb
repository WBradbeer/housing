# %% [markdown]
# # Housing Demo for Data Club

# %% [markdown]
# This is a demo notebook to explain some basic ML concepts in the SKLearn environment.

# %%
import pandas as pd
import numpy as np

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.linear_model import Lasso, Ridge, LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.impute import SimpleImputer
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import train_test_split

# %% [markdown]
# Get data and information from https://www.kaggle.com/c/house-prices-advanced-regression-techniques

# %% [markdown]
# ## Prep Data

# %%
df = pd.read_csv('data/train.csv')

# %% [markdown]
# Need to get dummy variables to deal with categoricals

# %%
df = df
df.MSSubClass = df.MSSubClass.astype(str)
df = pd.get_dummies(df)

# %%
X = df.drop(['SalePrice', 'Id'], axis=1).values
y = df.SalePrice.values

# %% [markdown]
# There are missing values so need to impute these

# %%
X = SimpleImputer().fit_transform(X)

# %% [markdown]
# ## Training a model

# %%
m_linear = LinearRegression().fit(X, y)
# Out:
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/base.py:485: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   linalg.lstsq(X, y)

# %%
m_linear.score(X, y)
# Out:
# 0.9336835673541317

# %% [markdown]
# Some things we did wrong:
#
# * We didnt look at the data
# * We didn't set a target
# * We tested our model on the same data we trained on

# %% [markdown]
# ## Train-Validation Split

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, random_state=0, test_size=0.2)

# %%
m_linear = LinearRegression().fit(X_train, y_train)
m_linear.score(X_val, y_val)
# Out:
# 0.4862796324549694

# %%
m_ridge = Ridge().fit(X_train, y_train)
m_ridge.score(X_val, y_val)
# Out:
# 0.6308230373105395

# %%
m_ridge2 = Ridge(alpha=0.5).fit(X_train, y_train)
m_ridge2.score(X_val, y_val)
# Out:
# 0.5880300791348494

# %% [markdown]
# Some things we did wrong:
#
# * What is the ridge model?
# * We iteratively looked at models, arbitrary stopping conditions
# * Testing each model once leaves an element of chance for which model performs best

# %% [markdown]
# ## Cross Validation

# %%
m_ridge = Ridge()
param_grid = {'alpha': [0.1, 1, 10]}
grid = GridSearchCV(m_ridge, param_grid, cv=5, return_train_score=False)
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'alpha': [0.1, 1, 10]}, pre_dispatch='2*n_jobs',
#        refit=True, return_train_score=False, scoring=None, verbose=0)

# %%
res = pd.DataFrame(grid.cv_results_)
res
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 0       0.005981      0.000543         0.000540        0.000040         0.1
# 1       0.005668      0.000303         0.000577        0.000104           1
# 2       0.005536      0.001874         0.000481        0.000045          10
#
#            params  split0_test_score  split1_test_score  split2_test_score  \
# 0  {'alpha': 0.1}           0.875625           0.763627           0.916745
# 1    {'alpha': 1}           0.897410           0.768181           0.928593
# 2   {'alpha': 10}           0.910037           0.762902           0.933358
#
#    split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0           0.877418           0.897386         0.866124        0.053447
# 1           0.881662           0.904139         0.875968        0.056029
# 2           0.879313           0.906750         0.878447        0.060321
#
#    rank_test_score
# 0                3
# 1                2
# 2                1

# %%
grid.score(X_val, y_val)
# Out:
# 0.7036441114654699

# %% [markdown]
# Some things we did wrong:
#
# * Doing better but we still had to do all of our preprocessing manually at the start
# * Any preprocessing that requires a fit call should be part of the CV process

# %% [markdown]
# ## Making a pipeline

# %%
X = df.drop(['SalePrice', 'Id'], axis=1).values
y = df.SalePrice.values

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, random_state=0, test_size=0.2)

# %%
pipe = Pipeline([
    ('impute', SimpleImputer(strategy="median")),
    ('scaler', MinMaxScaler()),
    ('regressor', Ridge())
])

param_grid =  {'impute__strategy': ["median", "mean"],
               'scaler': [MinMaxScaler(), RobustScaler(), None],
               'regressor': [Ridge(), Lasso()],
               'regressor__alpha': [0.1, 1, 10]}
 

grid = GridSearchCV(pipe, param_grid, cv=5, return_train_score=False)
grid.fit(X_train, y_train)
# Out:
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/willbradbeer/analytics/nlp_sentiment/nlp_sentiment/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=Pipeline(memory=None,
#      steps=[('impute', SimpleImputer(copy=True, fill_value=None, missing_values=nan,
#        strategy='median', verbose=0)), ('scaler', MinMaxScaler(copy=True, feature_range=(0, 1))), ('regressor', Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001))]),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'impute__strategy': ['median', 'mean'], 'scaler': [MinMaxScaler(copy=True, feature_range=(0, 1)), RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#        with_scaling=True), None], 'regressor': [Ridge(alpha=10, copy_X=True, fit_intercept=True, max_iter=None,
#    n...state=None,
#    selection='cyclic', tol=0.0001, warm_start=False)], 'regressor__alpha': [0.1, 1, 10]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#        scoring=None, verbose=0)

# %%
res = pd.DataFrame(grid.cv_results_)
res.sort_values('rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 25       0.132467      0.035121         0.001895        0.000352
# 7        0.094973      0.006260         0.001611        0.000181
# 3        0.021821      0.001376         0.001394        0.000124
# 21       0.016644      0.002646         0.001875        0.000174
# 26       0.013316      0.001714         0.001821        0.000385
# 8        0.021047      0.000972         0.001198        0.000093
# 4        0.090692      0.006982         0.001498        0.000074
# 22       0.113082      0.043490         0.001805        0.000285
# 5        0.019864      0.000597         0.001165        0.000049
# 23       0.031702      0.032416         0.001983        0.000358
# 33       0.174046      0.016678         0.001771        0.000274
# 15       0.185457      0.008845         0.001856        0.000605
# 24       0.038529      0.019310         0.003937        0.002344
# 6        0.023265      0.001161         0.001346        0.000031
# 34       0.306588      0.031375         0.002230        0.000255
# 16       0.301173      0.036256         0.002121        0.000122
# 35       0.176981      0.032750         0.001524        0.000150
# 17       0.173781      0.034925         0.001688        0.000345
# 0        0.025541      0.002619         0.001660        0.000316
# 18       0.048998      0.072447         0.001453        0.000190
# 1        0.120067      0.035932         0.001715        0.000208
# 19       0.084429      0.004451         0.001671        0.000179
# 2        0.025635      0.003845         0.001435        0.000203
# 20       0.022616      0.019358         0.001775        0.000357
# 30       0.223815      0.016098         0.002011        0.000232
# 12       0.237846      0.023944         0.001890        0.000199
# 13       0.304722      0.010638         0.002250        0.000356
# 31       0.327023      0.020548         0.002133        0.000222
# 14       0.239395      0.007499         0.001806        0.000210
# 32       0.226543      0.002720         0.001714        0.000171
# 9        0.219600      0.021722         0.002308        0.000346
# 27       0.275274      0.036669         0.002779        0.000155
# 10       0.298010      0.032372         0.002089        0.000149
# 11       0.228421      0.025672         0.001909        0.000391
# 28       0.335257      0.039288         0.002453        0.000450
# 29       0.232657      0.033906         0.001860        0.000235
#
#    param_impute__strategy                                    param_regressor  \
# 25                   mean  Ridge(alpha=10, copy_X=True, fit_intercept=Tru...
# 7                  median  Ridge(alpha=10, copy_X=True, fit_intercept=Tru...
# 3                  median  Ridge(alpha=10, copy_X=True, fit_intercept=Tru...
# 21                   mean  Ridge(alpha=10, copy_X=True, fit_intercept=Tru...
# 26                   mean  Ridge(alpha=10, copy_X=True, fit_intercept=Tru...
# 8                  median  Ridge(alpha=10, copy_X=True, fit_intercept=Tru...
# 4                  median  Ridge(alpha=10, copy_X=True, fit_intercept=Tru...
# 22                   mean  Ridge(alpha=10, copy_X=True, fit_intercept=Tru...
# 5                  median  Ridge(alpha=10, copy_X=True, fit_intercept=Tru...
# 23                   mean  Ridge(alpha=10, copy_X=True, fit_intercept=Tru...
# 33                   mean  Lasso(alpha=10, copy_X=True, fit_intercept=Tru...
# 15                 median  Lasso(alpha=10, copy_X=True, fit_intercept=Tru...
# 24                   mean  Ridge(alpha=10, copy_X=True, fit_intercept=Tru...
# 6                  median  Ridge(alpha=10, copy_X=True, fit_intercept=Tru...
# 34                   mean  Lasso(alpha=10, copy_X=True, fit_intercept=Tru...
# 16                 median  Lasso(alpha=10, copy_X=True, fit_intercept=Tru...
# 35                   mean  Lasso(alpha=10, copy_X=True, fit_intercept=Tru...
# 17                 median  Lasso(alpha=10, copy_X=True, fit_intercept=Tru...
# 0                  median  Ridge(alpha=10, copy_X=True, fit_intercept=Tru...
# 18                   mean  Ridge(alpha=10, copy_X=True, fit_intercept=Tru...
# 1                  median  Ridge(alpha=10, copy_X=True, fit_intercept=Tru...
# 19                   mean  Ridge(alpha=10, copy_X=True, fit_intercept=Tru...
# 2                  median  Ridge(alpha=10, copy_X=True, fit_intercept=Tru...
# 20                   mean  Ridge(alpha=10, copy_X=True, fit_intercept=Tru...
# 30                   mean  Lasso(alpha=10, copy_X=True, fit_intercept=Tru...
# 12                 median  Lasso(alpha=10, copy_X=True, fit_intercept=Tru...
# 13                 median  Lasso(alpha=10, copy_X=True, fit_intercept=Tru...
# 31                   mean  Lasso(alpha=10, copy_X=True, fit_intercept=Tru...
# 14                 median  Lasso(alpha=10, copy_X=True, fit_intercept=Tru...
# 32                   mean  Lasso(alpha=10, copy_X=True, fit_intercept=Tru...
# 9                  median  Lasso(alpha=10, copy_X=True, fit_intercept=Tru...
# 27                   mean  Lasso(alpha=10, copy_X=True, fit_intercept=Tru...
# 10                 median  Lasso(alpha=10, copy_X=True, fit_intercept=Tru...
# 11                 median  Lasso(alpha=10, copy_X=True, fit_intercept=Tru...
# 28                   mean  Lasso(alpha=10, copy_X=True, fit_intercept=Tru...
# 29                   mean  Lasso(alpha=10, copy_X=True, fit_intercept=Tru...
#
#    param_regressor__alpha                                       param_scaler  \
# 25                     10  RobustScaler(copy=True, quantile_range=(25.0, ...
# 7                      10  RobustScaler(copy=True, quantile_range=(25.0, ...
# 3                       1      MinMaxScaler(copy=True, feature_range=(0, 1))
# 21                      1      MinMaxScaler(copy=True, feature_range=(0, 1))
# 26                     10                                               None
# 8                      10                                               None
# 4                       1  RobustScaler(copy=True, quantile_range=(25.0, ...
# 22                      1  RobustScaler(copy=True, quantile_range=(25.0, ...
# 5                       1                                               None
# 23                      1                                               None
# 33                     10      MinMaxScaler(copy=True, feature_range=(0, 1))
# 15                     10      MinMaxScaler(copy=True, feature_range=(0, 1))
# 24                     10      MinMaxScaler(copy=True, feature_range=(0, 1))
# 6                      10      MinMaxScaler(copy=True, feature_range=(0, 1))
# 34                     10  RobustScaler(copy=True, quantile_range=(25.0, ...
# 16                     10  RobustScaler(copy=True, quantile_range=(25.0, ...
# 35                     10                                               None
# 17                     10                                               None
# 0                     0.1      MinMaxScaler(copy=True, feature_range=(0, 1))
# 18                    0.1      MinMaxScaler(copy=True, feature_range=(0, 1))
# 1                     0.1  RobustScaler(copy=True, quantile_range=(25.0, ...
# 19                    0.1  RobustScaler(copy=True, quantile_range=(25.0, ...
# 2                     0.1                                               None
# 20                    0.1                                               None
# 30                      1      MinMaxScaler(copy=True, feature_range=(0, 1))
# 12                      1      MinMaxScaler(copy=True, feature_range=(0, 1))
# 13                      1  RobustScaler(copy=True, quantile_range=(25.0, ...
# 31                      1  RobustScaler(copy=True, quantile_range=(25.0, ...
# 14                      1                                               None
# 32                      1                                               None
# 9                     0.1      MinMaxScaler(copy=True, feature_range=(0, 1))
# 27                    0.1      MinMaxScaler(copy=True, feature_range=(0, 1))
# 10                    0.1  RobustScaler(copy=True, quantile_range=(25.0, ...
# 11                    0.1                                               None
# 28                    0.1  RobustScaler(copy=True, quantile_range=(25.0, ...
# 29                    0.1                                               None
#
#                                                params  split0_test_score  \
# 25  {'impute__strategy': 'mean', 'regressor': Ridg...           0.910205
# 7   {'impute__strategy': 'median', 'regressor': Ri...           0.909961
# 3   {'impute__strategy': 'median', 'regressor': Ri...           0.899908
# 21  {'impute__strategy': 'mean', 'regressor': Ridg...           0.900006
# 26  {'impute__strategy': 'mean', 'regressor': Ridg...           0.910037
# 8   {'impute__strategy': 'median', 'regressor': Ri...           0.909797
# 4   {'impute__strategy': 'median', 'regressor': Ri...           0.897503
# 22  {'impute__strategy': 'mean', 'regressor': Ridg...           0.897615
# 5   {'impute__strategy': 'median', 'regressor': Ri...           0.897290
# 23  {'impute__strategy': 'mean', 'regressor': Ridg...           0.897403
# 33  {'impute__strategy': 'mean', 'regressor': Lass...           0.895277
# 15  {'impute__strategy': 'median', 'regressor': La...           0.895037
# 24  {'impute__strategy': 'mean', 'regressor': Ridg...           0.898704
# 6   {'impute__strategy': 'median', 'regressor': Ri...           0.898579
# 34  {'impute__strategy': 'mean', 'regressor': Lass...           0.893484
# 16  {'impute__strategy': 'median', 'regressor': La...           0.893232
# 35  {'impute__strategy': 'mean', 'regressor': Lass...           0.893256
# 17  {'impute__strategy': 'median', 'regressor': La...           0.892998
# 0   {'impute__strategy': 'median', 'regressor': Ri...           0.879255
# 18  {'impute__strategy': 'mean', 'regressor': Ridg...           0.879282
# 1   {'impute__strategy': 'median', 'regressor': Ri...           0.875656
# 19  {'impute__strategy': 'mean', 'regressor': Ridg...           0.875684
# 2   {'impute__strategy': 'median', 'regressor': Ri...           0.875591
# 20  {'impute__strategy': 'mean', 'regressor': Ridg...           0.875618
# 30  {'impute__strategy': 'mean', 'regressor': Lass...           0.868779
# 12  {'impute__strategy': 'median', 'regressor': La...           0.868781
# 13  {'impute__strategy': 'median', 'regressor': La...           0.869160
# 31  {'impute__strategy': 'mean', 'regressor': Lass...           0.869154
# 14  {'impute__strategy': 'median', 'regressor': La...           0.869122
# 32  {'impute__strategy': 'mean', 'regressor': Lass...           0.869116
# 9   {'impute__strategy': 'median', 'regressor': La...           0.848801
# 27  {'impute__strategy': 'mean', 'regressor': Lass...           0.848786
# 10  {'impute__strategy': 'median', 'regressor': La...           0.847644
# 11  {'impute__strategy': 'median', 'regressor': La...           0.847641
# 28  {'impute__strategy': 'mean', 'regressor': Lass...           0.847629
# 29  {'impute__strategy': 'mean', 'regressor': Lass...           0.847625
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 25           0.771442           0.933014           0.877463
# 7            0.771292           0.933083           0.877443
# 3            0.780749           0.928274           0.877914
# 21           0.780803           0.928261           0.877911
# 26           0.762879           0.933348           0.879307
# 8            0.762714           0.933423           0.879292
# 4            0.769568           0.928477           0.881330
# 22           0.769635           0.928420           0.881332
# 5            0.768102           0.928639           0.881653
# 23           0.768170           0.928582           0.881654
# 33           0.766531           0.920966           0.888364
# 15           0.766463           0.921042           0.888356
# 24           0.793328           0.922619           0.854946
# 6            0.793276           0.922618           0.854939
# 34           0.765786           0.916013           0.886882
# 16           0.765723           0.916150           0.886881
# 35           0.765197           0.916080           0.886989
# 17           0.765136           0.916226           0.886988
# 0            0.766432           0.918684           0.879920
# 18           0.766442           0.918655           0.879914
# 1            0.763793           0.916733           0.877385
# 19           0.763803           0.916699           0.877378
# 2            0.763617           0.916766           0.877415
# 20           0.763626           0.916731           0.877408
# 30           0.762265           0.899640           0.876140
# 12           0.762216           0.899669           0.876144
# 13           0.760487           0.898305           0.871907
# 31           0.760543           0.898274           0.871861
# 14           0.760425           0.898315           0.871922
# 32           0.760480           0.898283           0.871876
# 9            0.759831           0.899736           0.849477
# 27           0.759822           0.899728           0.849410
# 10           0.759870           0.899810           0.847945
# 11           0.759864           0.899811           0.847946
# 28           0.759861           0.899803           0.847877
# 29           0.759856           0.899804           0.847877
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 25           0.906635         0.879731        0.057005                1
# 7            0.906932         0.879721        0.057077                2
# 3            0.905727         0.878491        0.051482                3
# 21           0.905550         0.878484        0.051449                4
# 26           0.906737         0.878437        0.060327                5
# 8            0.907026         0.878425        0.060406                6
# 4            0.904205         0.876188        0.055481                7
# 22           0.904029         0.876178        0.055435                8
# 5            0.904292         0.875966        0.056075                9
# 23           0.904117         0.875956        0.056029               10
# 33           0.907646         0.875719        0.055772               11
# 15           0.907737         0.875689        0.055804               12
# 24           0.903532         0.874618        0.046322               13
# 6            0.903682         0.874611        0.046346               14
# 34           0.906576         0.873709        0.054958               15
# 16           0.906688         0.873695        0.055000               16
# 35           0.906553         0.873575        0.055187               17
# 17           0.906668         0.873563        0.055229               18
# 0            0.898985         0.868620        0.053163               19
# 18           0.898939         0.868611        0.053149               20
# 1            0.897403         0.866158        0.053383               21
# 19           0.897363         0.866149        0.053369               22
# 2            0.897415         0.866124        0.053457               23
# 20           0.897375         0.866115        0.053443               24
# 30           0.892322         0.859787        0.050043               25
# 12           0.892307         0.859782        0.050065               26
# 13           0.891484         0.858229        0.050176               27
# 31           0.891495         0.858225        0.050148               28
# 14           0.891484         0.858213        0.050201               29
# 32           0.891494         0.858210        0.050173               30
# 9            0.886586         0.848854        0.048893               31
# 27           0.886604         0.848837        0.048897               32
# 10           0.886409         0.848303        0.048868               33
# 11           0.886409         0.848302        0.048870               34
# 28           0.886430         0.848287        0.048873               35
# 29           0.886430         0.848286        0.048875               36

# %%
grid.score(X_val, y_val)
# Out:
# 0.7072562932539285

# %% [markdown]
# How can we do better?

# %% [markdown]
# ## More ML!!!??

# %%
pipe = Pipeline([
    ('impute', SimpleImputer(strategy="mean")),
    ('scaler', MinMaxScaler()),
    ('regressor', Ridge())
])

param_grid = [{'scaler': [MinMaxScaler(), RobustScaler()],
               'regressor': [RandomForestRegressor(n_estimators=100)],
               'regressor__min_samples_split': [5, 10],
               'regressor__max_features': ['sqrt', 0.3],
              },
              {'scaler': [MinMaxScaler(), RobustScaler()],
               'regressor': [GradientBoostingRegressor(loss='huber')],
               'regressor__max_depth': [2, 3],
               'regressor__n_estimators': [500, 1000],
               'regressor__max_features': ['sqrt', 0.3],
              },
              {'scaler': [RobustScaler()],
               'regressor': [Ridge(alpha=10)],
              }
             ]

grid = GridSearchCV(pipe, param_grid, cv=5, return_train_score=False)
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=Pipeline(memory=None,
#      steps=[('impute', SimpleImputer(copy=True, fill_value=None, missing_values=nan, strategy='mean',
#        verbose=0)), ('scaler', MinMaxScaler(copy=True, feature_range=(0, 1))), ('regressor', Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001))]),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid=[{'scaler': [MinMaxScaler(copy=True, feature_range=(0, 1)), RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#        with_scaling=True)], 'regressor': [RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=0.3, max_leaf_node...t_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)]}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#        scoring=None, verbose=0)

# %%
res = pd.DataFrame(grid.cv_results_)
res.sort_values('rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 24       0.076905      0.002828         0.001493        0.000065
# 23       3.427067      0.142039         0.004953        0.000081
# 4        0.572238      0.025881         0.009182        0.000296
# 16       0.975334      0.044585         0.003345        0.000109
# 17       1.019371      0.014867         0.003437        0.000059
# 5        0.605458      0.018138         0.009237        0.000761
# 21       1.736963      0.076984         0.003391        0.000248
# 6        0.496943      0.013928         0.008755        0.000892
# 19       2.079374      0.069987         0.006105        0.001063
# 22       3.333590      0.073307         0.005015        0.000140
# 7        0.525362      0.009111         0.008381        0.000073
# 11       1.386735      0.051035         0.004136        0.000200
# 9        0.706715      0.028944         0.002767        0.000097
# 18       1.912279      0.062833         0.005721        0.001089
# 12       0.996306      0.047501         0.003367        0.000834
# 10       1.392582      0.034455         0.004286        0.000390
# 20       1.662617      0.067924         0.003365        0.000166
# 8        0.658244      0.020322         0.003066        0.000645
# 15       2.126202      0.049108         0.004177        0.000197
# 13       1.107755      0.029851         0.002856        0.000095
# 0        0.200275      0.014089         0.009436        0.000943
# 1        0.268198      0.015407         0.009649        0.000586
# 14       2.033867      0.036369         0.003999        0.000188
# 2        0.174108      0.016633         0.008582        0.000287
# 3        0.227718      0.015226         0.008136        0.000133
#
#                                       param_regressor  \
# 24  Ridge(alpha=10, copy_X=True, fit_intercept=Tru...
# 23  ([DecisionTreeRegressor(criterion='friedman_ms...
# 4   (DecisionTreeRegressor(criterion='mse', max_de...
# 16  ([DecisionTreeRegressor(criterion='friedman_ms...
# 17  ([DecisionTreeRegressor(criterion='friedman_ms...
# 5   (DecisionTreeRegressor(criterion='mse', max_de...
# 21  ([DecisionTreeRegressor(criterion='friedman_ms...
# 6   (DecisionTreeRegressor(criterion='mse', max_de...
# 19  ([DecisionTreeRegressor(criterion='friedman_ms...
# 22  ([DecisionTreeRegressor(criterion='friedman_ms...
# 7   (DecisionTreeRegressor(criterion='mse', max_de...
# 11  ([DecisionTreeRegressor(criterion='friedman_ms...
# 9   ([DecisionTreeRegressor(criterion='friedman_ms...
# 18  ([DecisionTreeRegressor(criterion='friedman_ms...
# 12  ([DecisionTreeRegressor(criterion='friedman_ms...
# 10  ([DecisionTreeRegressor(criterion='friedman_ms...
# 20  ([DecisionTreeRegressor(criterion='friedman_ms...
# 8   ([DecisionTreeRegressor(criterion='friedman_ms...
# 15  ([DecisionTreeRegressor(criterion='friedman_ms...
# 13  ([DecisionTreeRegressor(criterion='friedman_ms...
# 0   (DecisionTreeRegressor(criterion='mse', max_de...
# 1   (DecisionTreeRegressor(criterion='mse', max_de...
# 14  ([DecisionTreeRegressor(criterion='friedman_ms...
# 2   (DecisionTreeRegressor(criterion='mse', max_de...
# 3   (DecisionTreeRegressor(criterion='mse', max_de...
#
#    param_regressor__max_features param_regressor__min_samples_split  \
# 24                           NaN                                NaN
# 23                           0.3                                NaN
# 4                            0.3                                  5
# 16                          sqrt                                NaN
# 17                          sqrt                                NaN
# 5                            0.3                                  5
# 21                           0.3                                NaN
# 6                            0.3                                 10
# 19                          sqrt                                NaN
# 22                           0.3                                NaN
# 7                            0.3                                 10
# 11                          sqrt                                NaN
# 9                           sqrt                                NaN
# 18                          sqrt                                NaN
# 12                           0.3                                NaN
# 10                          sqrt                                NaN
# 20                           0.3                                NaN
# 8                           sqrt                                NaN
# 15                           0.3                                NaN
# 13                           0.3                                NaN
# 0                           sqrt                                  5
# 1                           sqrt                                  5
# 14                           0.3                                NaN
# 2                           sqrt                                 10
# 3                           sqrt                                 10
#
#                                          param_scaler  \
# 24  RobustScaler(copy=True, quantile_range=(25.0, ...
# 23  RobustScaler(copy=True, quantile_range=(25.0, ...
# 4       MinMaxScaler(copy=True, feature_range=(0, 1))
# 16      MinMaxScaler(copy=True, feature_range=(0, 1))
# 17  RobustScaler(copy=True, quantile_range=(25.0, ...
# 5   RobustScaler(copy=True, quantile_range=(25.0, ...
# 21  RobustScaler(copy=True, quantile_range=(25.0, ...
# 6       MinMaxScaler(copy=True, feature_range=(0, 1))
# 19  RobustScaler(copy=True, quantile_range=(25.0, ...
# 22      MinMaxScaler(copy=True, feature_range=(0, 1))
# 7   RobustScaler(copy=True, quantile_range=(25.0, ...
# 11  RobustScaler(copy=True, quantile_range=(25.0, ...
# 9   RobustScaler(copy=True, quantile_range=(25.0, ...
# 18      MinMaxScaler(copy=True, feature_range=(0, 1))
# 12      MinMaxScaler(copy=True, feature_range=(0, 1))
# 10      MinMaxScaler(copy=True, feature_range=(0, 1))
# 20      MinMaxScaler(copy=True, feature_range=(0, 1))
# 8       MinMaxScaler(copy=True, feature_range=(0, 1))
# 15  RobustScaler(copy=True, quantile_range=(25.0, ...
# 13  RobustScaler(copy=True, quantile_range=(25.0, ...
# 0       MinMaxScaler(copy=True, feature_range=(0, 1))
# 1   RobustScaler(copy=True, quantile_range=(25.0, ...
# 14      MinMaxScaler(copy=True, feature_range=(0, 1))
# 2       MinMaxScaler(copy=True, feature_range=(0, 1))
# 3   RobustScaler(copy=True, quantile_range=(25.0, ...
#
#    param_regressor__max_depth param_regressor__n_estimators  \
# 24                        NaN                           NaN
# 23                          3                          1000
# 4                         NaN                           NaN
# 16                          3                           500
# 17                          3                           500
# 5                         NaN                           NaN
# 21                          3                           500
# 6                         NaN                           NaN
# 19                          3                          1000
# 22                          3                          1000
# 7                         NaN                           NaN
# 11                          2                          1000
# 9                           2                           500
# 18                          3                          1000
# 12                          2                           500
# 10                          2                          1000
# 20                          3                           500
# 8                           2                           500
# 15                          2                          1000
# 13                          2                           500
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 14                          2                          1000
# 2                         NaN                           NaN
# 3                         NaN                           NaN
#
#                                                params  split0_test_score  \
# 24  {'regressor': Ridge(alpha=10, copy_X=True, fit...           0.910205
# 23  {'regressor': ([DecisionTreeRegressor(criterio...           0.906974
# 4   {'regressor': (DecisionTreeRegressor(criterion...           0.898711
# 16  {'regressor': ([DecisionTreeRegressor(criterio...           0.891590
# 17  {'regressor': ([DecisionTreeRegressor(criterio...           0.905740
# 5   {'regressor': (DecisionTreeRegressor(criterion...           0.899490
# 21  {'regressor': ([DecisionTreeRegressor(criterio...           0.911448
# 6   {'regressor': (DecisionTreeRegressor(criterion...           0.900787
# 19  {'regressor': ([DecisionTreeRegressor(criterio...           0.900059
# 22  {'regressor': ([DecisionTreeRegressor(criterio...           0.910691
# 7   {'regressor': (DecisionTreeRegressor(criterion...           0.889296
# 11  {'regressor': ([DecisionTreeRegressor(criterio...           0.903636
# 9   {'regressor': ([DecisionTreeRegressor(criterio...           0.902893
# 18  {'regressor': ([DecisionTreeRegressor(criterio...           0.891348
# 12  {'regressor': ([DecisionTreeRegressor(criterio...           0.897095
# 10  {'regressor': ([DecisionTreeRegressor(criterio...           0.907236
# 20  {'regressor': ([DecisionTreeRegressor(criterio...           0.892919
# 8   {'regressor': ([DecisionTreeRegressor(criterio...           0.892266
# 15  {'regressor': ([DecisionTreeRegressor(criterio...           0.887297
# 13  {'regressor': ([DecisionTreeRegressor(criterio...           0.903423
# 0   {'regressor': (DecisionTreeRegressor(criterion...           0.873219
# 1   {'regressor': (DecisionTreeRegressor(criterion...           0.878899
# 14  {'regressor': ([DecisionTreeRegressor(criterio...           0.896336
# 2   {'regressor': (DecisionTreeRegressor(criterion...           0.872774
# 3   {'regressor': (DecisionTreeRegressor(criterion...           0.865258
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 24           0.771442           0.933014           0.877463
# 23           0.762762           0.921228           0.890701
# 4            0.793180           0.904778           0.857722
# 16           0.734588           0.909027           0.894779
# 17           0.736368           0.918232           0.872243
# 5            0.790836           0.900334           0.851611
# 21           0.747680           0.908246           0.863159
# 6            0.806674           0.899013           0.839870
# 19           0.757521           0.917524           0.852188
# 22           0.727752           0.919672           0.876613
# 7            0.795893           0.900532           0.842301
# 11           0.710563           0.918981           0.884055
# 9            0.721077           0.905310           0.877392
# 18           0.700256           0.919276           0.873365
# 12           0.694748           0.901941           0.894365
# 10           0.664024           0.916885           0.910914
# 20           0.713275           0.917598           0.865038
# 8            0.706441           0.903049           0.884840
# 15           0.703657           0.917829           0.879180
# 13           0.688419           0.901615           0.900860
# 0            0.791010           0.883206           0.822247
# 1            0.784945           0.886906           0.823773
# 14           0.657399           0.910750           0.868846
# 2            0.789617           0.875669           0.808494
# 3            0.794899           0.872915           0.803040
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 24           0.906635         0.879731        0.057005                1
# 23           0.908364         0.877969        0.058473                2
# 4            0.903977         0.871658        0.042981                3
# 16           0.925376         0.871005        0.069320                4
# 17           0.921185         0.870709        0.069446                5
# 5            0.905845         0.869608        0.044019                6
# 21           0.915778         0.869228        0.063730                7
# 6            0.897755         0.868820        0.038669                8
# 19           0.915118         0.868456        0.060292                9
# 22           0.903681         0.867643        0.071479               10
# 7            0.899536         0.865502        0.040847               11
# 11           0.905627         0.864520        0.077863               12
# 9            0.912168         0.863715        0.072359               13
# 18           0.919019         0.860592        0.082118               14
# 12           0.911398         0.859836        0.082835               15
# 10           0.899928         0.859719        0.098106               16
# 20           0.902836         0.858289        0.074585               17
# 8            0.905150         0.858286        0.076360               18
# 15           0.902113         0.857959        0.078353               19
# 13           0.895313         0.857857        0.084853               20
# 0            0.890936         0.852116        0.038853               21
# 1            0.883079         0.851517        0.040513               22
# 14           0.906904         0.847979        0.096509               23
# 2            0.884015         0.846113        0.039061               24
# 3            0.878744         0.842975        0.036270               25

# %%
grid.score(X_val, y_val)

# %%
grid.best_params_

# %% [markdown]
# ## Prepare submission

# %%
test = pd.read_csv('data/test.csv')
test.MSSubClass = test.MSSubClass.astype(str)
test = pd.get_dummies(test)
X_test = test.drop('Id', axis=1).loc[:, df_dummy.drop(['SalePrice', 'Id'], axis=1).columns].values

pipe = Pipeline([
    ('impute', SimpleImputer(strategy="median")),
    ('scaler', RobustScaler()),
    ('regressor', Ridge(alpha=10))
])
pipe.fit(X,y)
y_pred = pipe.predict(X_test)

# %%
pd.DataFrame({'SalePrice': y_pred}, index=pd.read_csv('data/test.csv').Id).to_csv('data/pred.csv')

# %% [markdown]
# ## Tips to improve this

# %% [markdown]
# * Actually look at the data
# * Understand the models you are using
# * Do some kind of feature selection (but include in pipeline)
